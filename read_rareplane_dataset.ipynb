# %%
# Import libraries
import pandas as pd

# %%
aircraft_real_coco_file_path = "/mnt/d/RarePlanes/aircraft_real_coco.json"
aircraft_real_df = pd.read_json(aircraft_real_coco_file_path)
# aircraft_real_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-e0b64877c22b> in <module>
#       1 aircraft_real_coco_file_path = "/mnt/d/RarePlanes/aircraft_real_coco.json"
# ----> 2 aircraft_real_df = pd.read_json(aircraft_real_coco_file_path)
#       3 # aircraft_real_df.head()
#       4
#
# ~/gpu-1/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/gpu-1/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
# ...
